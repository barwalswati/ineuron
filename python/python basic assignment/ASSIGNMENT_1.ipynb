# %%
1. In the below elements which of them are values or an expression?
eg:- values can be integer or string and expressions will be mathematical operators.

'hello'
87.8
/
6
# Out:
#   Input In [3]
#     eg:- values can be integer or string and expressions will be mathematical operators.
#                 ^
# SyntaxError: invalid syntax

# %%
answer1.:-
Values are:-'hello',87.8,6
Expressions are:-/,*

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [markdown]
# Variables:- are used to store the data. String:- String is a collection of alphabets, words or other characters. A variable can hold a string,but a string can not hold a variable. A Variable is a store of information, and a String is a type of information you would store in a Variable. Example:- Strings = 'Hello World'. Here "strings" is variable name and "Hello world" is called string.

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
# Numeric Types:-int , float , complex
# Sequence Types:-list , tuple , range
# Mapping Type:-dict

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?¶

# %% [markdown]
# Expressions are made up of one or more operands and operators. Operands are the objects of the operation, such as variables or values, and operators are the symbols or keywords that perform the operation on the operands.The expression produces some value or result after being interpreted by the interpreter.

# %%
x=10
x=x+10 # this is an expression
print (x)
# Out:
# 20

# %% [markdown]
# 5.This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# A combination of operands and operators is called an expression. The expression in Python produces some value or result after being interpreted by the Python interpreter.
# An expression in Python is very different from statements in Python. A statement is not evaluated for some results. A statement is used for creating variables or for displaying values.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
#
# bacon + 1

# %% [markdown]
# After running the code, the variable bacon will contain the value 22.
# The last line of the code bacon + 1 is an expression, it calculates the value of 22+1 , but it doesnot assign the output to any variable. The value of bacon remains 22.

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
#
# 'spam' * 3

# %% [markdown]
# 'spam' + 'spamspam' would be "spamspamspam", this is called concatenation.
# Addition operator+ is used to concatenates the two strings.
#
# 'spam' * 3 would be "spamspamspam", this is called repetition.
# Multiplication operator * is used to repeat the string for a given number of times

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# Variable name is not start with a number thats why eggs is a valid variable name and 100 is invalid.A variable name cannot start with a number.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# int(): This function returns the integer version of a value. For example, int(7.12) would return 7.
#
# float(): This function returns the floating-point version of a value. For example, float(5) would return 5.0
#
# str(): This function returns the string version of a value. For example, str(7) would return "7"

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# This expression causes an error because in this expression 'I have eaten' and 'burritos' are strings, while 99 is an integer. In order to fix the error write (99) as a string.'i have eaten'+99'+'burritos'.

# %%
'ihave eaten'+'99'+'burritos'
# Out:
# 'ihave eaten99burritos'
